# %% [markdown]
# # Katas 10

# %% [markdown]
# ## Dataset

# %% [markdown]
# Continuer l'exploration du dataset kickstarter

# %% [markdown]
# Calculer le montant moyen par donnateur et créer une nouvelle colonne 'average_pledge' dans le dataframe

# %%
import pandas as pd
df = pd.read_csv('ks-projects-201801.csv',sep=',',error_bad_lines=False,encoding ='latin1', header=0, index_col=0)
df.columns
# Out:
# Index(['name', 'category', 'main_category', 'currency', 'deadline', 'goal',
#        'launched', 'pledged', 'state', 'backers', 'country', 'usd pledged',
#        'usd_pledged_real', 'usd_goal_real'],
#       dtype='object')

# %%
df
# Out:
#                                                         name   \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# 1000014025                               Monarch Espresso Bar
# 1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 100004195   STUDIO IN THE SKY - A Documentary Feature Film...
# 100004721                                 Of Jesus and Madmen
# 100005484                                    Lisa Lim New CD!
# 1000055792                                 The Cottage Market
# 1000056157  G-Spot Place for Gamers to connect with eachot...
# 1000064368                                     Survival Rings
# ...

# %%
#df.info(verbose=True)
df['average_pledge'] = df['usd_goal_real']  / (df['backers'])
df.head()
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency    deadline     goal             launched  \
# ID
# 1000002330    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28
# 1000003930  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57
# 1000004038  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50
# 1000007540         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11
# 1000011046  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03
#
# ...

# %%
#df['usd pledged '].unique
df.groupby(['backers ', 'usd pledged ']).mean()
# Out:
#                          Unnamed: 16
# backers    usd pledged
# 0          0                     NaN
#            0.75240299            NaN
#            1                     NaN
#            10                    NaN
#            100                   NaN
#            109                   NaN
#            12.19647407           NaN
#            131                   NaN
#            14.4547314            NaN
#            145                   NaN
#            15                    NaN
#            168.435237            NaN
#            2.57295948            NaN
#            2.9035038             NaN
#            20                    NaN
#            200                   NaN
#            218                   NaN
#            24                    NaN
#            25                    NaN
#            28                    NaN
#            3                     NaN
#            30                    NaN
#            40                    NaN
#            42.18276645           NaN
# ...

# %% [markdown]
# Afficher l'écart moyen entre le montant récolté et le montant demandé pour les projets n'ayant par réussi

# %%
#projet n'ayant pas reussi 
s = df.groupby(['state ', 'goal ']).std().reset_index()
s.loc[s['state '] == "failed"]
# Out:
#       state       goal   Unnamed: 16
# 2351  failed       0.15          NaN
# 2352  failed        0.5          NaN
# 2353  failed          1          NaN
# 2354  failed       1.85          NaN
# 2355  failed         10          NaN
# 2356  failed        100          NaN
# 2357  failed       1000          NaN
# 2358  failed      10000          NaN
# 2359  failed     100000          NaN
# 2360  failed    1000000          NaN
# 2361  failed   10000000          NaN
# 2362  failed  100000000          NaN
# 2363  failed     100001          NaN
# 2364  failed      10001          NaN
# 2365  failed      10007          NaN
# 2366  failed       1001          NaN
# 2367  failed      10010          NaN
# 2368  failed      10016          NaN
# 2369  failed       1002          NaN
# 2370  failed      10020          NaN
# 2371  failed      10025          NaN
# 2372  failed      10030          NaN
# 2373  failed   10035.35          NaN
# 2374  failed     100385          NaN
# ...

# %% [markdown]
# Calculer le montant median par categorie

# %%
 df.groupby(['goal ', 'category ']).median().reset_index()
# Out:
#                 goal                            category   Unnamed: 16
# 0                0.01                      Conceptual Art          NaN
# 1                0.01                             Fiction          NaN
# 2                0.15                              Shorts          NaN
# 3                 0.5                         Documentary          NaN
# 4                   1                            Academic          NaN
# 5                   1                         Accessories          NaN
# 6                   1                           Animation          NaN
# 7                   1                         Anthologies          NaN
# 8                   1                             Apparel          NaN
# 9                   1                                Apps          NaN
# 10                  1                                 Art          NaN
# 11                  1                           Art Books          NaN
# ...

# %% [markdown]
# One hot encoder la colonne status

# %%
#encoder la colonne

# %% [markdown]
# ## Modèle

# %% [markdown]
# Créer un réseau feedforward à 3 couches avec keras

# %% [markdown]
# Coder la fonction `convolution(np_image, patch)` faisant la convolution d'une image par un neurone convolutif

# %% [markdown]
# ## Math

# %% [markdown]
# Donner la formule de la fonction de coût de la régression logistique

# %%
log(1)=0
def

# %% [markdown]
# Calculer à la main le gradient de $f(x_1, x_2, x_3) =  ln(x_1^{x_2}) + exp(\theta) * cos(x_3^2)$
